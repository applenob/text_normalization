# %%
import pandas as pd
import numpy as np
import pickle as pkl

# %%
letters_name = "../output/letter_dict.pkl"
with open(letters_name, "rb") as f:
    letter_dict = pkl.load(f)

# %%
letter_dict
# Out:
# {'LETTERS': {'': 4,
#   'NRETAS': 0,
#   'MXDOWN': 0,
#   'WBGG-': 3,
#   'N. Y.': 239,
#   'DLCM': 0,
#   'MfE': 15,
#   'CUBENSI': 1,
#   'SNPMD': 0,
#   'F.U.N.': 0,
#   'EHOK': 0,
#   'ic': 77,
#   'pregnane-': 0,
#   'écu': 6,
#   "UBO's": 0,
#   'LPROF': 3,
#   'NZDSM': 0,
#   "WOZA's": 0,
#   'H. W. T.R.': 0,
#   'ROSG': 0,
#   'CKCL-': 0,
#   'KQRS-': 4,
#   'P.J. O.S.': 0,
#   'BCDA': 7,
#   'VFD': 34,
#   'K.K.S.': 4,
#   'Amrda': 0,
#   'SLSPG': 0,
#   'Deau': 0,
#   'ELTUNT': 0,
#   'WMVA': 2,
#   'HRTF': 13,
#   'LeslieVS-': 0,
#   'SOFTEC': 0,
#   'CJMT': 3,
#   'PPRP': 0,
#   'kftl': 0,
#   'INSERM': 16,
#   'emp': 6,
#   'Krcil': 0,
#   'BY': 22,
#   'Yaoyotl': 0,
#   'Cwne': 0,
#   'RAINSTONE': 0,
#   'EWNI': 1,
#   'KHUSA': 0,
#   'LMTV': 0,
#   'FBRs': 0,
#   'TIRC': 5,
#   'EGTF': 0,
#   'ISFG': 3,
#   'WQED-': 5,
#   'KRSL-': 1,
#   'ACSCNs': 0,
#   'CCAS-': 0,
#   'J.S.S.F.': 0,
#   'FMNH': 8,
#   'Dsign': 3,
#   'KIACTA': 0,
#   'AzaC': 0,
#   'WFNQ': 0,
# ...

# %%
len(letter_dict["LETTERS"].keys())
# Out:
# 227433

# %%
len(letter_dict["PLAIN"].keys())
# Out:
# 3036

# %%
count = 0

for k in letter_dict["PLAIN"]:
    if letter_dict["PLAIN"][k] >= letter_dict["LETTERS"][k]:
        count += 1
        print(k, letter_dict["PLAIN"][k], letter_dict["LETTERS"][k])
count
# Out:
#  36 4
# P 27581 7324
# WAD 30 7
# MIDI 616 0
# POCAHONTAS 0 0
# MONET 2 1
# FUN 90 3
# ABER 0 0
# GRAVE 20 1
# EME 69 2
# SHEP 2 1
# ONCA 7 0
# OSU 428 5
# DIOXANE 0 0
# MIE 8 1
# CRY 49 3
# DARWARS 4 0
# EAST 385 2
# UNICEF 904 3
# MESS 20 0
# PRESENTS 67 0
# EAEA 3 0
# ANIMAL 42 0
# ANSI 421 1
# SOFTEC 7 0
# ARN 35 0
# ARIA 5877 9
# H 26958 7126
# NEWSMAKER 6 0
# CORA 5 0
# IB 1122 40
# NORTHWEST 9 0
# WESTWARD 1 0
# SAB 132 2
# TWO 420 26
# EFFORT 21 0
# AID 114 2
# DUE 44 0
# AMR 146 5
# TIS 71 12
# TREK 46 2
# AAN 32 4
# VICENTE 5 0
# o 8886 161
# BINA 17 4
# BOUT 2 1
# BAD 120 2
# MR 2047 191
# TRADITIONS 4 0
# DERP 3 0
# HELIX 15 0
# FORTH 22 1
# UNE 66 0
# NaCl 78 1
# GORMAN 9 0
# ACT 3524 13
# COMMONWEALTH 56 0
# ICA 319 12
# DAR 142 1
# VLK 0 0
# GAL 76 27
# TAXI 27 0
# EHA 17 0
# WHO 2032 10
# CAR 445 3
# MOTION 37 1
# HASH 10 0
# PHO 8 0
# VOLTA 2 0
# VEG 4 0
# MARK 157 10
# MEC 154 0
# RI 786 15
# HOMETOWN 7 0
# OVERDOSE 0 0
# SEAS 43 1
# ACTION 206 0
# BURNS 33 0
# ...

# %%
letter_dict["LETTERS"]["of"]
# Out:
# 16

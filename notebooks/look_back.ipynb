# %%
import pandas as pd

# %%
good_df = pd.read_csv("../output/res_16.v2.5.final.4.9.csv")
now_df = pd.read_csv("../output/res_16.v2.5.debug.final.csv")

# %%
now_df["good"] = good_df["after"]
diff_df = now_df.loc[now_df["after"] != now_df["good"]]
diff_df.shape
# Out:
# (147, 6)

# %%
diff_df["class_pred"].value_counts()
# Out:
# DATE         91
# MEASURE      40
# PLAIN        15
# TELEPHONE     1
# Name: class_pred, dtype: int64

# %%
diff_df
# Out:
#               id                                              after  \
# 1092        95_4                                      twenty twenty
# 3036       254_6                                    carbon di oxide
# 7997       641_7                                    carbon di oxide
# 15492     1217_7                                    carbon di oxide
# 19859     1548_8                                   sixteen thirteen
# 29242     2270_6                                     twenty sixteen
# 29609     2296_0                               nineteen forty seven
# 32076     2489_8                            eighteen million square
# 35548    2756_11                                     twelve percent
# 38031     2938_6                                nineteen sixty four
# 44592    3444_31                    two hundred thirty six kilobits
# 47559     3674_8                                thirty nine percent
# 48824     3770_2                                    carbon di oxide
# ...

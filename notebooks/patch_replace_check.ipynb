# %%
import pandas as pd
import numpy as np

# %%
change_file = "../output/patch_replace_change.csv"

# %%
change_df = pd.read_csv(change_file, index_col=0)

# %%
change_df["class_pred"].value_counts()
# Out:
# LETTERS       388
# ORDINAL       106
# VERBATIM       56
# DATE           44
# MEASURE        37
# PLAIN          28
# MONEY          23
# TIME           12
# TELEPHONE      10
# PUNCT           4
# ELECTRONIC      4
# ADDRESS         2
# CARDINAL        1
# FRACTION        1
# Name: class_pred, dtype: int64

# %%
change_df.loc[146855]
# Out:
# id                                                    11148_7
# after                                                 3/37506
# before                                                3/37506
# class_pred                                           CARDINAL
# max_prob                                             0.408591
# patch         three thirty seven thousand five hundred sixths
# Name: 146855, dtype: object

# %%
change_df
# Out:
#               id                                   after  \
# 4197      348_12                                 o s t i
# 7347       598_1                                 g a t a
# 7822       630_8                               o p a l s
# 7980       639_9                                 e p u b
# 11865      947_5                         n a k a m u r a
# 15089    1189_11                                   u l m
# 15995     1255_6                                   i v a
# 16723     1313_7                                   c a v
# 18736    1466_20                                     f e
# 19036    1488_16                                 i r b's
# 19985     1558_1                                   i g g
# 20528     1594_5                                   t r o
# 22227     1721_5                             r e a p e r
# 22790     1770_2                                 s w i m
# 23199    1800_10                                   b b q
# ...
